# %% [markdown]
# <h3> Mock Interview Python Screening test </h3>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as pltdataframe 
import seaborn as sns
dataframe = pd.read_csv("adult_census_data.csv")

# %%
#dataframe = pd.read_csv("adult_census_data.csv",header=None)

# %%
dataframe.head(5)
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %% [markdown]
# <b> Q1. After importing the adult_census_data.csv file, please filter this to include only the following criteria: </b>
# <p>
#
# <li> State-Gov</li>
# <li> Bachelors </li>
# <li> Never-Married </li>
# <li> Adm-Clerical </li>
# <li> Not-in-familiy </li>
# <li> White </li>
# <li> Male </li>
# <li> United States </li>
# <li> <=50K </li>
#
# <b> Feel free to any method to complete this tasks. However, we recommend you use either list filtering [], or .loc to complete this task.</b>

# %% [markdown]
# <b> Put your code below </b>

# %%
df=dataframe.iloc[:,[1,3,5,6,7,8,9,13,14]]
df
# Out:
#                State-gov    Bachelors        Never-married  \
# 0       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1                Private      HS-grad             Divorced
# 2                Private         11th   Married-civ-spouse
# 3                Private    Bachelors   Married-civ-spouse
# 4                Private      Masters   Married-civ-spouse
# ...                  ...          ...                  ...
# 32555            Private   Assoc-acdm   Married-civ-spouse
# 32556            Private      HS-grad   Married-civ-spouse
# 32557            Private      HS-grad              Widowed
# 32558            Private      HS-grad        Never-married
# 32559       Self-emp-inc      HS-grad   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   United-States  \
# 0         Exec-managerial         Husband   White     Male   United-States
# 1       Handlers-cleaners   Not-in-family   White     Male   United-States
# ...

# %% [markdown]
# <b> Currently, the dataframe you are using has the following column names: </b>
#
# [' State-gov', ' Bachelors', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' United-States', ' <=50K']
#
#
# <b> Q2. Please re-name all the newly filtered columns in the pandas DataFrame to the following: </b>
#
# Employment Type, Degree Status, Marriage-Status, Job-Role, Family-Role, Ethnicity, Gender, Country, Earnings
#
# E.g. State-Gov becomes Employment Type, Bachelors becomes Degree Status, etc.

# %% [markdown]
# <b> Put your code below </b>

# %%
df.columns=['Employment Type', 'Degree Status', 'Marriage-Status', 'Job-Role', 'Family-Role', 'Ethnicity', 'Gender',
            'County', 'Earnings']
df.head()
# Out:
#      Employment Type Degree Status      Marriage-Status            Job-Role  \
# 0   Self-emp-not-inc     Bachelors   Married-civ-spouse     Exec-managerial
# 1            Private       HS-grad             Divorced   Handlers-cleaners
# 2            Private          11th   Married-civ-spouse   Handlers-cleaners
# 3            Private     Bachelors   Married-civ-spouse      Prof-specialty
# 4            Private       Masters   Married-civ-spouse     Exec-managerial
#
#       Family-Role Ethnicity   Gender          County Earnings
# 0         Husband     White     Male   United-States    <=50K
# 1   Not-in-family     White     Male   United-States    <=50K
# 2         Husband     Black     Male   United-States    <=50K
# 3            Wife     Black   Female            Cuba    <=50K
# 4            Wife     White   Female   United-States    <=50K

# %%
df_trim=df.apply(lambda x: x.str.strip())
df_trim
# Out:
#         Employment Type Degree Status     Marriage-Status           Job-Role  \
# 0      Self-emp-not-inc     Bachelors  Married-civ-spouse    Exec-managerial
# 1               Private       HS-grad            Divorced  Handlers-cleaners
# 2               Private          11th  Married-civ-spouse  Handlers-cleaners
# 3               Private     Bachelors  Married-civ-spouse     Prof-specialty
# 4               Private       Masters  Married-civ-spouse    Exec-managerial
# ...                 ...           ...                 ...                ...
# 32555           Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32556           Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32557           Private       HS-grad             Widowed       Adm-clerical
# 32558           Private       HS-grad       Never-married       Adm-clerical
# 32559      Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
# ...

# %% [markdown]
# <b> Q3. The Job Role Columns holds the job information for each individual in this census snapshot. Using this column, create a Bar Chart that shows the count of 'Unique' Jobs per Job Group in the "Job-Role" Column in ascending order, as per the provided image below </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
#df_job_grouped = df_trim.groupby("Job-Role")["Job-Role"].count()
df_job_grouped = df_trim["Job-Role"].value_counts()
df_job_grouped
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3769
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: Job-Role, dtype: int64

# %%
df_job_grouped.sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b> Q4. Please create two bar plots as per below that show:
#
#     1) The number of individuals who have a High School Graduate Diploma AND earn <=50K in the United States
#     2) The number of individuals who have a High School Graduate Diploma AND earn >50K in the United States
#
# Please note you will be looking specifically at the *Job Role* column

# %% [markdown]
# <b> Put Your Code Below </b>

# %%
df_job_1= df_trim[ (df_trim["Degree Status"]=="HS-grad") & (df_trim["Earnings"]=="<=50K")
                  &(df_trim["County"]=="United-States")]
df_job_1
# Out:
#         Employment Type Degree Status     Marriage-Status           Job-Role  \
# 1               Private       HS-grad            Divorced  Handlers-cleaners
# 15     Self-emp-not-inc       HS-grad       Never-married    Farming-fishing
# 16              Private       HS-grad       Never-married  Machine-op-inspct
# 20              Private       HS-grad           Separated      Other-service
# 23              Private       HS-grad            Divorced       Tech-support
# ...                 ...           ...                 ...                ...
# 32539         State-gov       HS-grad           Separated       Adm-clerical
# 32540                 ?       HS-grad           Separated                  ?
# 32541                 ?       HS-grad  Married-civ-spouse                  ?
# 32557           Private       HS-grad             Widowed       Adm-clerical
# 32558           Private       HS-grad       Never-married       Adm-clerical
#
# ...

# %%
df_job_1_grouped=df_job_1["Job-Role"].value_counts()
df_job_1_grouped_sorted=df_job_1_grouped.sort_values(ascending=False)
df_job_1_grouped_sorted
# Out:
# Craft-repair         1403
# Adm-clerical         1130
# Other-service        1068
# Sales                 806
# Machine-op-inspct     797
# Transport-moving      624
# Handlers-cleaners     533
# Exec-managerial       514
# ?                     451
# Farming-fishing       335
# Protective-serv       159
# Prof-specialty        156
# Tech-support          106
# Priv-house-serv        33
# Armed-Forces            4
# Name: Job-Role, dtype: int64

# %%
df_job_1_grouped_sorted.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df_job_2= df_trim[ (df_trim["Degree Status"]=="HS-grad") & (df_trim["Earnings"]==">50K")
                  &(df_trim["County"]=="United-States")]
df_job_2
# Out:
#         Employment Type Degree Status     Marriage-Status           Job-Role  \
# 6      Self-emp-not-inc       HS-grad  Married-civ-spouse    Exec-managerial
# 66              Private       HS-grad  Married-civ-spouse       Adm-clerical
# 83              Private       HS-grad            Divorced       Craft-repair
# 85            Local-gov       HS-grad  Married-civ-spouse    Protective-serv
# 104        Self-emp-inc       HS-grad  Married-civ-spouse       Craft-repair
# ...                 ...           ...                 ...                ...
# 32414  Self-emp-not-inc       HS-grad  Married-civ-spouse       Craft-repair
# 32461      Self-emp-inc       HS-grad  Married-civ-spouse       Craft-repair
# 32517         Local-gov       HS-grad  Married-civ-spouse       Craft-repair
# 32556           Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559      Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
# ...

# %%
df_job_2_grouped=df_job_2["Job-Role"].value_counts()
df_job_2_grouped
# Out:
# Craft-repair         390
# Exec-managerial      250
# Sales                192
# Transport-moving     162
# Adm-clerical         154
# Machine-op-inspct    129
# Prof-specialty        49
# Protective-serv       47
# Farming-fishing       46
# Other-service         43
# ?                     42
# Tech-support          42
# Handlers-cleaners     37
# Name: Job-Role, dtype: int64

# %%
df_job_2_grouped.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <H2> Challenge Question </H2>
#
# <b> Q5. Which Job Role has the highest <i> proportion </i> of individuals who earn >50K? </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
df_high_earn = df_trim [df_trim["Earnings"]==">50K"]
df_high_earn
# Out:
#         Employment Type Degree Status     Marriage-Status           Job-Role  \
# 6      Self-emp-not-inc       HS-grad  Married-civ-spouse    Exec-managerial
# 7               Private       Masters       Never-married     Prof-specialty
# 8               Private     Bachelors  Married-civ-spouse    Exec-managerial
# 9               Private  Some-college  Married-civ-spouse    Exec-managerial
# 10            State-gov     Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...           ...                 ...                ...
# 32538                 ?     Doctorate  Married-civ-spouse                  ?
# 32544         Local-gov    Assoc-acdm  Married-civ-spouse       Adm-clerical
# 32553           Private       Masters  Married-civ-spouse    Exec-managerial
# 32556           Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559      Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
# ...

# %%
df_high_earn_JobRole_count=df_high_earn["Job-Role"].value_counts()
df_high_earn_JobRole_count
# Out:
# Exec-managerial      1968
# Prof-specialty       1859
# Sales                 983
# Craft-repair          929
# Adm-clerical          507
# Transport-moving      320
# Tech-support          283
# Machine-op-inspct     250
# Protective-serv       211
# ?                     191
# Other-service         137
# Farming-fishing       115
# Handlers-cleaners      86
# Armed-Forces            1
# Priv-house-serv         1
# Name: Job-Role, dtype: int64

# %%
df_high_earn_JobRole_perc=df_high_earn["Job-Role"].value_counts(normalize=True)*100
df_high_earn_JobRole_perc
# Out:
# Exec-managerial      25.098839
# Prof-specialty       23.708711
# Sales                12.536666
# Craft-repair         11.847979
# Adm-clerical          6.466012
# Transport-moving      4.081112
# Tech-support          3.609234
# Machine-op-inspct     3.188369
# Protective-serv       2.690983
# ?                     2.435914
# Other-service         1.747226
# Farming-fishing       1.466650
# Handlers-cleaners     1.096799
# Armed-Forces          0.012753
# Priv-house-serv       0.012753
# Name: Job-Role, dtype: float64

# %%
df_high_earn_JobRole_perc.idxmax()
# Out:
# 'Exec-managerial'
